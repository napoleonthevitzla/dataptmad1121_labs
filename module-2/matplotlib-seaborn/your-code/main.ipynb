# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import math
import plotly.express as px  
import plotly.io as pio


import cufflinks as cf

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1 Plot A (x,y)
# Method 1
plt.plot(x, y, color= 'k')
plt.plot(x, z, color= 'r')
plt.show()

# %%
# Method 2

plot_2 = fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,6))
ax[0].plot(x, y, color = 'k')
ax[1].plot(x, z, color = 'red')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
#plot_2 = fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,6))
#ax[0].plot(x, y, color = 'k')
#ax[1].plot(x, z, color = 'red')


# Method 2
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(x, y, color= 'k', lw= 2)
ax2.plot(y, z, color= 'red', lw= 2)
fig.tight_layout()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

# your code here
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 5))
ax1.plot(x, y, color= 'k', lw= 2)
ax2.plot(y, z, color= 'r', lw= 2)

ax1.set_title('Gráfico 1')
ax2.set_title('Gráfico 2')

ax1.set_xlabel('Eje x 1')
ax2.set_xlabel('Eje x 2')

ax1.set_ylabel('Eje y 1')
ax2.set_ylabel('Eje y 2')

# Gracias a tightout puedo dar espacio a graficos, margenes e indices
fig.tight_layout()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

xaxis = np.linspace(0, 4, 1000)
y1 = lambda x: x**2
y2 = lambda x: np.exp(x)

#plt.plot(xaxis, y1(xaxis))
#plt.plot(xaxis, y2(xaxis))
#plt.xscale('log')
plt.plot(xaxis, y1(xaxis), color= 'r', lw= 3, label= 'Y-1')
plt.plot(xaxis, y2(xaxis), color= 'b', lw= 3, label= 'Y-2')
plt.legend()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
monthly_steps = fitbit.groupby(by= ['Months_encoded'])['Steps'].median()

fig = plt.figure(figsize= (12, 4))
plt.bar(monthly_steps.index, monthly_steps.values, color= 'b')

plt.xticks(monthly_steps.index, ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.savefig('../figures/monthly_steps.png')


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

weekly_steps = fitbit.groupby(by= ['Work_or_Weekend'])['Steps'].median()

fig = plt.figure(figsize= (6, 2))
plt.barh(weekly_steps.index, weekly_steps.values, height= 0.9, color= 'gray', align='center', )
plt.yticks([0, 1], ['Weekend', 'Work'])
plt.savefig('../figures/work_or_weekend.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include='number')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
#Seaborn
sns.set(style="dark")

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
#matplotlib
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,6))
ax.hist(titanic['Age'])
plt.style.use('classic')
plt.show()

# %%
# your code here
#Seaborn
sns.distplot(titanic['Age'])
# Out:
# /Users/antoniohuerta/miniconda3/envs/ironhack/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
f, axes = plt.subplots(3, 1, figsize=(7, 7), sharex=True)
sns.despine(left=True)


# histogram binsize 10 , red
sns.distplot(titanic['Age'], color="r", ax=axes[0], bins= 10)

# histogram binsize 20, green
sns.distplot(titanic['Age'], color="g", ax=axes[1], bins= 20)

# histogram binsize 50, blue
sns.distplot(titanic['Age'], color="b", ax=axes[2], bins= 50)
# Out:
# /Users/antoniohuerta/miniconda3/envs/ironhack/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# /Users/antoniohuerta/miniconda3/envs/ironhack/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# /Users/antoniohuerta/miniconda3/envs/ironhack/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning:
#
# ...

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
A medida que aumentamos bins number mayor resolución de la vista pero menos valores
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
# histogram binsize 10 , red
# your code here

sns.distplot(titanic['Age'], color="g", ax=axes[2], bins= 50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/30/vsgs8bp94b7b17m8zr60lgnh0000gn/T/ipykernel_42667/4290956422.py in <module>
#       3 # your code here
#       4
# ----> 5 sns.distplot(titanic['Age'], color="g", ax=axes[2], bins= 50)
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
# your code here
plt.hist(x=titanic['Gender'], bins=2)
# Out:
# (array([843., 466.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
# Method 2 - seaborn
# your code here
sns.barplot(titanic.Gender.value_counts().index, titanic.Gender.value_counts().values)
# Out:
# /Users/antoniohuerta/miniconda3/envs/ironhack/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
#sns.histplot(titanic, x="Pclass", bins=[1, 2, 3, 4]);

titanic['Pclass'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.boxplot(titanic.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb0d3eedb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb0d3ef6d50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb0d3eedb90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb0d3ef66d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb0d31ebbd0>],
#  'means': []}

# %%
"""
He usado el boxplot me indica la distribución de la edad de los tripulantes del titanic.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Me dice que la mayoría de tripulantes tenian cerca de 30 años.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
ax = sns.displot(titanic, x="Age")

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
cuantas personas tengo en cada rango de edad
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.catplot(x="Age", y="Gender", data=titanic)
